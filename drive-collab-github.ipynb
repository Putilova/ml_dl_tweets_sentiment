# %% [markdown]
# # How to use Google Colab with GitHub via Google Drive
# [source](https://medium.com/analytics-vidhya/how-to-use-google-colab-with-github-via-google-drive-68efb23a42d)

# %% [markdown]
# ### Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd drive/MyDrive/Github/
# Out:
# /content/drive/MyDrive/Github

# %%
#!echo "Test" > file1.txt

# %%
#!cat file1.txt

# %%
#!rm -f file1.txt

# %% [markdown]
# ## GitHub

# %%
from datetime import date

date1 = date(2022,3,18)
date2 = date.today()
expiration = 7
print(f"GitHub personal access token expires in {expiration - abs(date2-date1).days} days.")
# Out:
# GitHub personal access token expires in 7 days.

# %%
git_token = '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'
username = 'Putilova'
repository = 'ml_dl_tweets_sentiment'

# %% [markdown]
# Pull if repo exists on Drive

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Github/ml_dl_tweets_sentiment'

# %%
# %cd {repository}
# Out:
# /content/drive/MyDrive/Github/ml_dl_tweets_sentiment

# %%
# !git config --global user.email "email@gmail.com" 
# !git config --global user.name "Putilova"

# %%
# !git pull
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !ls -al
# Out:
# total 124
# drwx------ 2 root root  4096 Mar 21 15:36 _02_06_python_np_pd_plt
# drwx------ 2 root root  4096 Mar 21 15:36 _02_07_ml_classification
# drwx------ 2 root root  4096 Mar 21 15:37 _03_09_use_model
# drwx------ 2 root root  4096 Mar 21 15:37 _03_10_use_model_colab
# drwx------ 2 root root  4096 Mar 21 15:37 _04_11_flask_hello_world
# drwx------ 2 root root  4096 Mar 21 15:37 _04_12_classifier_rest_service
# drwx------ 2 root root  4096 Mar 21 15:37 _04_14_classifier_rest_service_on_GCP
# drwx------ 2 root root  4096 Mar 21 15:37 _04_16_google_cloud_functions_serverless_ml
# drwx------ 2 root root  4096 Mar 21 15:37 _04_17_colab_rest_api
# drwx------ 2 root root  4096 Mar 21 15:38 _05_20_save_export_reload_pytorch_models
# drwx------ 2 root root  4096 Mar 21 15:38 _05_21_pytorch_flask
# drwx------ 3 root root  4096 Mar 21 15:38 _05_22_tf_serving_save_export
# drwx------ 2 root root  4096 Mar 21 15:38 _05_24_tf_model_serving
# ...

# %% [markdown]
# Clone if repo is not on Drive

# %%
#rm -rf {repository}

# %%
# !git clone https://{git_token}@github.com/{username}/{repository} #drive/MyDrive/Github/{repository}
# Out:
# Cloning into 'ml_dl_tweets_sentiment'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), done.

# %%
# !ls -al {repository}
# Out:
# total 13
# drwx------ 8 root root 4096 Mar 21 20:11 .git
# -rw------- 1 root root 8776 Mar 21 20:11 README.md

# %%
#!rm -rf drive/MyDrive/Github/.*
#!rm -rf drive/MyDrive/Github/*

# %% [markdown]
# Send changes to GitHub

# %%
# %cd ml_dl_tweets_sentiment/
# Out:
# /content/drive/MyDrive/Github/ml_dl_tweets_sentiment

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	_02_06_python_np_pd_plt/
# 	_02_07_ml_classification/
# 	_03_09_use_model/
# 	_03_10_use_model_colab/
# 	_04_11_flask_hello_world/
# 	_04_12_classifier_rest_service/
# 	_04_14_classifier_rest_service_on_GCP/
# 	_04_16_google_cloud_functions_serverless_ml/
# 	_04_17_colab_rest_api/
# 	_05_20_save_export_reload_pytorch_models/
# 	_05_21_pytorch_flask/
# 	_05_22_tf_serving_save_export/
# 	_05_24_tf_model_serving/
# 	_05_25_pytorch_create_save_onnx/
# 	_06_28_text_classifier/
# 	_06_30_twitter_sentiment_analysis/
# 	_06_31_text_classifier_pytorch/
# 	_06_32_pytorch_nlp_rest/
# 	_06_33_twitter_pytorch_rest/
# 	_06_34_text_classifier_tensorflow/
# 	_06_35_tf_nlp_flask_rest/
# 	_06_36_tf_serverless/
# 	_06_37_pytorch_serverless/
# 	drive-collab-github.ipynb
# 	ml_dl_course.postman_collection.json
#
# ...

# %%
# !git add .

# %%
# !git commit -m "Updated"
# Out:
# [main 1b1a18d] Updated
#  60 files changed, 5323 insertions(+)
#  create mode 100644 _02_06_python_np_pd_plt/python_np_pd_plt.py
#  create mode 100644 _02_06_python_np_pd_plt/storepurchasedata.csv
#  create mode 100644 _02_07_ml_classification/classifier.pickle
#  create mode 100644 _02_07_ml_classification/ml_pipeline.ipynb
#  create mode 100644 _02_07_ml_classification/sc.pickle
#  create mode 100644 _03_09_use_model/use_model.py
#  create mode 100644 _03_10_use_model_colab/use_model_colab.ipynb
#  create mode 100644 _04_11_flask_hello_world/flask_hello_world.py
#  create mode 100644 _04_11_flask_hello_world/rest_client.py
#  create mode 100644 _04_12_classifier_rest_service/classifier_rest_service.py
#  create mode 100644 _04_12_classifier_rest_service/ml_rest_client.py
#  create mode 100644 _04_14_classifier_rest_service_on_GCP/_04_14_GCP_VM.txt
#  create mode 100644 _04_14_classifier_rest_service_on_GCP/classifier_rest_service_on_GCP.py
# ...

# %%
# !git push
# Out:
# Counting objects: 90, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (85/85), done.
# Writing objects: 100% (90/90), 13.80 MiB | 10.60 MiB/s, done.
# Total 90 (delta 23), reused 0 (delta 0)
# remote: Resolving deltas: 100% (23/23), done.
# To https://github.com/Putilova/ml_dl_tweets_sentiment
#    4f99701..1b1a18d  main -> main

# %% [markdown]
# If git push failed

# %%
# !git remote set-url origin https://{username}:{git_token}@github.com/{username}/{repository}.git
