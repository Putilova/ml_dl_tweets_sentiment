# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd drive/MyDrive/Github/ml_dl_tweets_sentiment
# Out:
# /content/drive/MyDrive/Github/ml_dl_tweets_sentiment

# %%
# %cd _04_17_colab_rest_api

# %%
import numpy as np
import pickle

# %%
# !pip install pyngrok
# Out:
# ...
#      |████████████████████████████████| 745 kB 5.4 MB/s
# ...
#   Created wheel for pyngrok: filename=pyngrok-5.1.0-py3-none-any.whl size=19007 sha256=6a38ac8d1adeec8abd2dea100dba11106c7063643b5d33a2ff37080037313454
#   Stored in directory: /root/.cache/pip/wheels/bf/e6/af/ccf6598ecefecd44104069371795cb9b3afbcd16987f6ccfb3
# Successfully built pyngrok
# ...

# %%
# !ngrok authtoken token
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
# !cat /root/.ngrok2/ngrok.yml

# %%
# !pip install flask

# %%
# !pip install flask-ngrok

# %%
#!wget -O classifier.pickle https://github.com/Putilova/ml_dl_tweets_sentiment/raw/main/classifier.pickle

# %%
#!wget -O sc.pickle https://github.com/Putilova/ml_dl_tweets_sentiment/raw/main/sc.pickle

# %%
classifier_colab = pickle.load(open('../_02_07_ml_classification/classifier.pickle','rb'))

# %%
scaler_colab = pickle.load(open(../_02_07_ml_classification/sc.pickle','rb'))

# %%
import requests

# %%
import os
import threading

from pyngrok import ngrok

# %%
os.environ["FLASK_ENV"] = "development"

# %%
app = Flask(__name__)
port = 5000

# Open a ngrok tunnel to the HTTP server
public_url = ngrok.connect(port).public_url
print(" * ngrok tunnel \"{}\" -> \"http://127.0.0.1:{}\"".format(public_url, port))

# Update any base URLs to use the public ngrok URL
app.config["BASE_URL"] = public_url

# ... Update inbound traffic via APIs to use the public-facing ngrok URL
# Out:
#  * ngrok tunnel "http://824b-35-225-85-145.ngrok.io" -> "http://127.0.0.1:5000"

# %%
@app.route('/predict',methods=['POST'])
def customer_behavior():
    request_data = request.get_json(force=True)
    age = request_data['age']
    salary = request_data['salary']
    print(age)
    print(salary)
    pred_proba = classifier_colab.predict_proba(scaler_colab.transform(np.array([[age,salary]])))[:,1]
    print(pred_proba)
    return "The prediction is {}".format(pred_proba)

# %%
# Start the Flask server in a new thread
thread = threading.Thread(target=app.run, kwargs={"use_reloader": False})
thread.start()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: development
#  * Debug mode: on
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)

# %%
import time
time.sleep(20)

thread.join()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-e3693d11e667> in <module>()
#       1 import time
# ----> 2 time.sleep(20)
#       3
#       4 thread.join()
#
# KeyboardInterrupt:
