# %%
# !pip install pyngrok
# Out:
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.7/dist-packages (5.1.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from pyngrok) (3.13)

# %%
# !pip install flask
# Out:
# Requirement already satisfied: flask in /usr/local/lib/python3.7/dist-packages (1.1.4)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from flask) (7.1.2)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from flask) (2.11.3)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from flask) (1.1.0)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from flask) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->flask) (2.0.1)

# %%
import os
import threading

from flask import Flask
from pyngrok import ngrok

# %%
os.environ["FLASK_ENV"] = "development"

# %%
# !ngrok authtoken token
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
# !cat /root/.ngrok2/ngrok.yml

# %%
app = Flask(__name__)
port = 5000

# Open a ngrok tunnel to the HTTP server
public_url = ngrok.connect(port).public_url
print(" * ngrok tunnel \"{}\" -> \"http://127.0.0.1:{}\"".format(public_url, port))

# Update any base URLs to use the public ngrok URL
app.config["BASE_URL"] = public_url

# ... Update inbound traffic via APIs to use the public-facing ngrok URL
# Out:
#  * ngrok tunnel "http://2a10-34-125-164-239.ngrok.io" -> "http://127.0.0.1:5000"

# %%
@app.route("/")
def hello():
	return "Hello from Google Colab"

# %%
# Start the Flask server in a new thread
thread = threading.Thread(target=app.run, kwargs={"use_reloader": False})
thread.start()

# %%
import time
time.sleep(10)

thread.join()
# Out:
# 127.0.0.1 - - [11/Mar/2022 17:08:25] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Mar/2022 17:08:35] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Mar/2022 17:09:37] "GET / HTTP/1.1" 200 -
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-214c71e61b14> in <module>()
#       2 time.sleep(10.0)
#       3
# ----> 4 thread.join()
#
# /usr/lib/python3.7/threading.py in join(self, timeout)
#    1042
#    1043         if timeout is None:
# -> 1044             self._wait_for_tstate_lock()
#    1045         else:
#    1046             # the behavior of a negative timeout isn't documented, but
#
# /usr/lib/python3.7/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1058         if lock is None:  # already determined that the C code is done
#    1059             assert self._is_stopped
# -> 1060         elif lock.acquire(block, timeout):
#    1061             lock.release()
#    1062             self._stop()
#
# KeyboardInterrupt:
