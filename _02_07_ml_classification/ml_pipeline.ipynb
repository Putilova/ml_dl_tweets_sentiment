# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd drive/MyDrive/Github/ml_dl_tweets_sentiment
# Out:
# /content/drive/MyDrive/Github/ml_dl_tweets_sentiment

# %%
# !git config --global user.email "my_email@gmail.com" 
# !git config --global user.name "Putilova"

# %%
# When GitHub files aren't in local Drive
# !git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/Putilova/ml_dl_tweets_sentiment
#    45b7ab9..2ee432b  main       -> origin/main
# Updating 45b7ab9..2ee432b
# Fast-forward
#  README.md | 1 +
#  1 file changed, 1 insertion(+)

# %%
# !ls
# Out:
# classifier.pickle		  textclassifier.pickle
# ml_pipeline.ipynb		  text_classifier_pytorch
# pytorch_nlp_rest.ipynb		  text_classifier_pytorch_1
# pytorch_serverless_main_w_exc.py  text_classifier_pytorch_101.ipynb
# README.md			  text_classifier_pytorch.ipynb
# Restaurant_Reviews.tsv.txt	  text_classifier_tensorflow.ipynb
# sc.pickle			  tfidfmodel.pickle
# storepurchasedata.csv		  tf_nlp_rest.ipynb
# text_classifier.ipynb		  tfserverless_main_w_exc.py
# text_classifier_model		  twitter_sentiment_analysis.ipynb
# text_classifier_model.zip	  twitter_sentiment_analysis_output_log.txt

# %%
# %cd _02_07_ml_classification
# Out:
# /content/drive/MyDrive/Github/ml_dl_tweets_sentiment/_02_07_ml_classification

# %%
# !ls
# Out:
# classifier.pickle  ml_pipeline.ipynb  sc.pickle

# %%
import numpy as np
import pandas as pd

# %%
training_data = pd.read_csv('../_02_06_python_np_pd_plt/storepurchasedata.csv')
training_data.describe()
# Out:
#              Age        Salary  Purchased
# count  40.000000     40.000000  40.000000
# mean   38.100000  49525.000000   0.550000
# std    12.557151  19046.484971   0.503831
# min    18.000000  20000.000000   0.000000
# 25%    27.750000  35000.000000   0.000000
# 50%    37.500000  48500.000000   1.000000
# 75%    47.250000  60000.000000   1.000000
# max    60.000000  95000.000000   1.000000

# %%
X = training_data.iloc[:, :-1].values
y = training_data.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =.20,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# minkowski is for ecledian distance
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)

# %%
# Model training
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = classifier.predict(X_test)
y_prob = classifier.predict_proba(X_test)[:,1]

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.875

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86         3
#            1       1.00      0.80      0.89         5
#
#     accuracy                           0.88         8
#    macro avg       0.88      0.90      0.87         8
# weighted avg       0.91      0.88      0.88         8

# %%
new_prediction = classifier.predict(sc.transform(np.array([[40,20000]])))
new_prediction_proba = classifier.predict_proba(sc.transform(np.array([[40,20000]])))[:,1]
print(f"Prediction: \t{new_prediction}, \tprobability: \t{new_prediction_proba}")
# Out:
# Prediction: 	[0], 	probability: 	[0.2]

# %%
new_pred = classifier.predict(sc.transform(np.array([[42,50000]])))
new_pred_proba = classifier.predict_proba(sc.transform(np.array([[42,50000]])))[:,1]
print(f"Prediction: \t{new_pred}, \tprobability: \t{new_pred_proba}")
# Out:
# Prediction: 	[1], 	probability: 	[0.8]

# %%
import pickle

# %%
# Picking the Model and Standard Scaler
model_file = "classifier.pickle"
pickle.dump(classifier, open(model_file,'wb'))

# %%
scaler_file = "sc.pickle"
pickle.dump(sc, open(scaler_file,'wb'))

# %%
# !ls -al
# Out:
# total 12478
# -rw------- 1 root root    2483 Mar 18 03:41 classifier.pickle
# drwx------ 8 root root    4096 Mar 18 03:40 .git
# -rw------- 1 root root   30694 Mar 18 03:41 ml_pipeline.ipynb
# -rw------- 1 root root   18665 Mar 18 03:40 pytorch_nlp_rest.ipynb
# -rw------- 1 root root    5549 Mar 18 03:40 pytorch_serverless_main_w_exc.py
# -rw------- 1 root root     188 Mar 18 03:40 README.md
# -rw------- 1 root root   61332 Mar 18 03:40 Restaurant_Reviews.tsv.txt
# -rw------- 1 root root     583 Mar 18 03:41 sc.pickle
# -rw------- 1 root root     502 Mar 18 03:40 storepurchasedata.csv
# -rw------- 1 root root   65498 Mar 18 03:40 text_classifier.ipynb
# drwx------ 3 root root    4096 Mar 18 03:40 text_classifier_model
# -rw------- 1 root root 5311513 Mar 18 03:40 text_classifier_model.zip
# -rw------- 1 root root 2995998 Mar 18 03:40 textclassifier.pickle
# -rw------- 1 root root 1943959 Mar 18 03:40 text_classifier_pytorch
# -rw------- 1 root root 1943051 Mar 18 03:40 text_classifier_pytorch_1
# -rw------- 1 root root  110232 Mar 18 03:40 text_classifier_pytorch_101.ipynb
# -rw------- 1 root root  100357 Mar 18 03:40 text_classifier_pytorch.ipynb
# -rw------- 1 root root   72397 Mar 18 03:40 text_classifier_tensorflow.ipynb
# -rw------- 1 root root   49677 Mar 18 03:40 tfidfmodel.pickle
# -rw------- 1 root root   23766 Mar 18 03:40 tf_nlp_rest.ipynb
# -rw------- 1 root root    5365 Mar 18 03:40 tfserverless_main_w_exc.py
# -rw------- 1 root root   21692 Mar 18 03:40 twitter_sentiment_analysis.ipynb
# -rw------- 1 root root     119 Mar 18 03:40 twitter_sentiment_analysis_output_log.txt

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/Github/ml_dl_tweets_sentiment

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	ml_pipeline.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# Add local Drive files to GitHub
# !git add .

# %%
# Add comment and send added files to GitHub
# !git commit -m "Modified files"
# Out:
# [main abdd9c9] Modified files
#  1 file changed, 1 insertion(+)
#  create mode 100644 ml_pipeline.ipynb

# %%
# Send to main
# !git push
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 6.57 KiB | 1.64 MiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/Putilova/ml_dl_tweets_sentiment
#    2ee432b..abdd9c9  main -> main

# %%
# On git push failure:
git_token = 'token'
username = 'Putilova'
repository = 'ml_dl_tweets_sentiment'
# !git remote set-url origin https://{username}:{git_token}@github.com/{username}/{repository}.git
