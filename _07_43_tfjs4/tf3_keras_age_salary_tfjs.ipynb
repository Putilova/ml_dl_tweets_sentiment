# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd drive/MyDrive/Github/ml_dl_tweets_sentiment
# Out:
# /content/drive/MyDrive/Github/ml_dl_tweets_sentiment

# %%
# %cd  _07_43_tfjs4
# Out:
# /content/drive/MyDrive/Github/ml_dl_tweets_sentiment/_07_43_tfjs4

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
#dataset = pd.read_csv('https://raw.githubusercontent.com/futurexskill/ml-model-deployment/main/storepurchasedata_large.csv')
dataset = pd.read_csv('../_05_20_save_export_reload_pytorch_models/storepurchasedata_large.csv')

# %%
dataset.head()
# Out:
#    Age  Salary  Purchased
# 0   18   20000          0
# 1   19   22000          0
# 2   20   24000          0
# 3   21   28000          0
# 4   22   60000          1

# %%
dataset.describe()
# Out:
#                Age        Salary    Purchased
# count  1554.000000   1554.000000  1554.000000
# mean     44.296010  57042.471042     0.694981
# std      17.462458  21209.244800     0.460564
# min      18.000000  20000.000000     0.000000
# 25%      27.000000  46000.000000     0.000000
# 50%      43.000000  60000.000000     1.000000
# 75%      62.000000  66000.000000     1.000000
# max      69.000000  96000.000000     1.000000

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =.20,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(10, activation='relu'),
  tf.keras.layers.Dense(10, activation='relu'),
  tf.keras.layers.Dense(2, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 39/39 [==============================] - 1s 2ms/step - loss: 0.7178 - accuracy: 0.5591
# Epoch 2/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.5825 - accuracy: 0.8286
# Epoch 3/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.4692 - accuracy: 0.9437
# Epoch 4/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.3704 - accuracy: 0.9501
# Epoch 5/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.2911 - accuracy: 0.9477
# Epoch 6/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.2320 - accuracy: 0.9453
# Epoch 7/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1899 - accuracy: 0.9533
# Epoch 8/50
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1626 - accuracy: 0.9525
# Epoch 9/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1457 - accuracy: 0.9541
# Epoch 10/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1358 - accuracy: 0.9566
# Epoch 11/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1294 - accuracy: 0.9533
# Epoch 12/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1260 - accuracy: 0.9541
# Epoch 13/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1239 - accuracy: 0.9541
# Epoch 14/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1218 - accuracy: 0.9541
# Epoch 15/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1205 - accuracy: 0.9541
# Epoch 16/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1194 - accuracy: 0.9541
# Epoch 17/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1188 - accuracy: 0.9541
# Epoch 18/50
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1178 - accuracy: 0.9533
# Epoch 19/50
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1174 - accuracy: 0.9541
# Epoch 20/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1167 - accuracy: 0.9533
# Epoch 21/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1169 - accuracy: 0.9541
# Epoch 22/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1165 - accuracy: 0.9517
# Epoch 23/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1158 - accuracy: 0.9517
# Epoch 24/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1161 - accuracy: 0.9525
# Epoch 25/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1153 - accuracy: 0.9541
# Epoch 26/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1146 - accuracy: 0.9525
# Epoch 27/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1144 - accuracy: 0.9517
# Epoch 28/50
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1140 - accuracy: 0.9517
# Epoch 29/50
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1140 - accuracy: 0.9517
# Epoch 30/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1133 - accuracy: 0.9517
# Epoch 31/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1127 - accuracy: 0.9533
# Epoch 32/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1134 - accuracy: 0.9517
# Epoch 33/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1124 - accuracy: 0.9525
# Epoch 34/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1119 - accuracy: 0.9517
# Epoch 35/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1112 - accuracy: 0.9525
# Epoch 36/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1112 - accuracy: 0.9525
# Epoch 37/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1107 - accuracy: 0.9525
# Epoch 38/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1105 - accuracy: 0.9525
# Epoch 39/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1101 - accuracy: 0.9525
# Epoch 40/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1097 - accuracy: 0.9525
# Epoch 41/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1098 - accuracy: 0.9525
# Epoch 42/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1101 - accuracy: 0.9525
# Epoch 43/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1092 - accuracy: 0.9525
# Epoch 44/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1086 - accuracy: 0.9525
# Epoch 45/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1088 - accuracy: 0.9525
# Epoch 46/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1087 - accuracy: 0.9525
# Epoch 47/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1086 - accuracy: 0.9533
# Epoch 48/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1083 - accuracy: 0.9533
# Epoch 49/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1090 - accuracy: 0.9533
# Epoch 50/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1081 - accuracy: 0.9525

# %%
loss, accuracy =model.evaluate(X_test, y_test)
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1174 - accuracy: 0.9550

# %%
loss
# Out:
# 0.11740833520889282

# %%
accuracy
# Out:
# 0.9549839496612549

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                30
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 162
# Trainable params: 162
# Non-trainable params: 0
# _________________________________________________________________

# %%
prediction1 = model.predict(sc.transform(np.array([[42,50000]])))[:,1]
prediction1
# Out:
# array([0.6086768], dtype=float32)

# %%
predict2 = model.predict(sc.transform(np.array([[20,40000]])))[:,1]
predict2
# Out:
# array([0.0053079], dtype=float32)

# %%
model.save('customer_behavior_model/1')
# Out:
# INFO:tensorflow:Assets written to: customer_behavior_model/1/assets

# %%
# !ls
# Out:
# customer_behavior_model  group1-shard1of1.bin  tf3_keras_age_salary_tfjs.ipynb
# customermodel.zip	 model.json	       tfjsdemo.html

# %%
# !ls customer_behavior_model/1
# Out:
# assets	keras_metadata.pb  saved_model.pb  variables

# %%
from tensorflow.keras.models import load_model

# %%
cust_model = load_model('customer_behavior_model/1/')

# %%
prediction3 = cust_model.predict(sc.transform(np.array([[42,50000]])))[:,1]
prediction3
# Out:
# array([0.6086768], dtype=float32)

# %%
predict4 = cust_model.predict(sc.transform(np.array([[20,40000]])))[:,1]
predict4
# Out:
# array([0.0053079], dtype=float32)

# %%
sc.transform(np.array([[20,40000]]))
# Out:
# array([[-1.40863043, -0.81755432]])

# %%
sc.transform(np.array([[42,50000]]))
# Out:
# array([[-0.15065689, -0.34524533]])

# %%
# !ls
# Out:
# customer_behavior_model  group1-shard1of1.bin		  tfjsdemo.html
# customermodel.zip	 tf3_keras_age_salary_tfjs.ipynb

# %%
# !zip -r customermodel.zip customer_behavior_model
# Out:
# updating: customer_behavior_model/ (stored 0%)
# updating: customer_behavior_model/1/ (stored 0%)
# updating: customer_behavior_model/1/variables/ (stored 0%)
# updating: customer_behavior_model/1/variables/variables.data-00000-of-00001 (deflated 58%)
# updating: customer_behavior_model/1/variables/variables.index (deflated 64%)
# updating: customer_behavior_model/1/assets/ (stored 0%)
# updating: customer_behavior_model/1/saved_model.pb (deflated 88%)
# updating: customer_behavior_model/1/keras_metadata.pb (deflated 86%)

# %%
# !ls
# Out:
# customer_behavior_model  group1-shard1of1.bin  tf3_keras_age_salary_tfjs.ipynb
# customermodel.zip	 model.json	       tfjsdemo.html

# %%
from google.colab import files

# %%
# !pip install tensorflowjs
# Out:
# Collecting tensorflowjs
#   Downloading tensorflowjs-3.14.0-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 3.6 MB/s
# Requirement already satisfied: six<2,>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (1.15.0)
# Requirement already satisfied: tensorflow<3,>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (2.8.0)
# Requirement already satisfied: tensorflow-hub<0.13,>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (0.12.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.5.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.44.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.0.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.17.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.24.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.8.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (57.4.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (13.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.3.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.21.5)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 19.5 MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.14.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.10.0.2)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.1.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.8.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow<3,>=2.1.0->tensorflowjs) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow<3,>=2.1.0->tensorflowjs) (1.5.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (2.23.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (3.3.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow<3,>=2.1.0->tensorflowjs) (3.2.0)
# Installing collected packages: tf-estimator-nightly, tensorflowjs
# Successfully installed tensorflowjs-3.14.0 tf-estimator-nightly-2.8.0.dev2021122109

# %%
import tensorflowjs as tfjs

# %%
tfjs.__version__
# Out:
# '3.14.0'

# %%
tfjs.converters.save_keras_model(model, "/")

# %%
# !ls
# Out:
# customer_behavior_model  group1-shard1of1.bin  tf3_keras_age_salary_tfjs.ipynb
# customermodel.zip	 model.json	       tfjsdemo.html

# %%
# !cat model.json
# Out:
# cat: model.json: No such file or directory

# %%
#from google.colab import files

# %%
#files.download('model.json')

# %%
#files.download('group1-shard1of1.bin')
